# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("adult_with_headers.csv")
data
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
data.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# Initialize StandardScaler
standard_scaler = StandardScaler()

# Apply scaling
standard_scaled = standard_scaler.fit_transform(data)

# Convert to DataFrame for easier interpretation
standard_scaled_df = pd.DataFrame(standard_scaled, columns=data.columns)

print("\nStandard Scaled Data:")
print(standard_scaled_df)
# Out:
# Standard Scaled Data:
#             age  workclass    fnlwgt  education  education_num  \
# 0      0.030671   2.150579 -1.063611  -0.335437       1.134739
# 1      0.837109   1.463736 -1.008707  -0.335437       1.134739
# 2     -0.042642   0.090050  0.245079   0.181332      -0.420060
# 3      1.057047   0.090050  0.425801  -2.402511      -1.197459
# 4     -0.775768   0.090050  1.408176  -0.335437       1.134739
# ...         ...        ...       ...        ...            ...
# 32556 -0.849080   0.090050  0.639741  -0.852205       0.746039
# 32557  0.103983   0.090050 -0.335433   0.181332      -0.420060
# 32558  1.423610   0.090050 -0.358777   0.181332      -0.420060
# 32559 -1.215643   0.090050  0.110960   0.181332      -0.420060
# 32560  0.983734   0.776893  0.929893   0.181332      -0.420060
#
#        marital_status  occupation  relationship      race       sex  \
# 0            0.921634   -1.317809     -0.277805  0.393668  0.703071
# ...

# %%
# Initialize MinMaxScaler
min_max_scaler = MinMaxScaler()

# Apply scaling
min_max_scaled = min_max_scaler.fit_transform(data)

# Convert to DataFrame for easier interpretation
min_max_scaled_df = pd.DataFrame(min_max_scaled, columns=data.columns)

print("\nMin-Max Scaled Data:")
print(min_max_scaled_df)
# Out:
# Min-Max Scaled Data:
#             age  workclass    fnlwgt  education  education_num  \
# 0      0.301370      0.875  0.044302   0.600000       0.800000
# 1      0.452055      0.750  0.048238   0.600000       0.800000
# 2      0.287671      0.500  0.138113   0.733333       0.533333
# 3      0.493151      0.500  0.151068   0.066667       0.400000
# 4      0.150685      0.500  0.221488   0.600000       0.800000
# ...         ...        ...       ...        ...            ...
# 32556  0.136986      0.500  0.166404   0.466667       0.733333
# 32557  0.315068      0.500  0.096500   0.733333       0.533333
# 32558  0.561644      0.500  0.094827   0.733333       0.533333
# 32559  0.068493      0.500  0.128499   0.733333       0.533333
# 32560  0.479452      0.625  0.187203   0.733333       0.533333
#
#        marital_status  occupation  relationship  race  sex  capital_gain  \
# 0            0.666667    0.071429           0.2   1.0  1.0      0.021740
# ...

# %% [markdown]
# # Key Differences
#
# 1)Standard Scaling:
# * Centers the data around 0 with a standard deviation of 1.
# * Useful for algorithms sensitive to the magnitude of data, like SVM or Logistic Regression.
#
# 2)Min-Max Scaling:
# * Scales all values to a fixed range, typically [0, 1].
# * Useful for algorithms like Neural Networks where scaled inputs help in faster convergence.

# %%
sns.barplot(data=data,x=data['education'],y=data['age'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=data['race'],data=data)
plt.xticks(rotation=90)
plt.show()

# %%
data['workclass'].unique()
# Out:
# array([7, 6, 4, 1, 2, 0, 5, 8, 3], dtype=int64)

# %%
data_one_hot = pd.get_dummies(data, columns=['workclass','education','relationship','marital_status','occupation'], drop_first=True)
print(data_one_hot)
# Out:
#        age  fnlwgt  education_num  race  sex  capital_gain  capital_loss  \
# 0       39   77516             13     4    1          2174             0
# 1       50   83311             13     4    1             0             0
# 2       38  215646              9     4    1             0             0
# 3       53  234721              7     2    1             0             0
# 4       28  338409             13     2    0             0             0
# ...    ...     ...            ...   ...  ...           ...           ...
# 32556   27  257302             12     4    0             0             0
# 32557   40  154374              9     4    1             0             0
# 32558   58  151910              9     4    0             0             0
# 32559   22  201490              9     4    1             0             0
# 32560   52  287927              9     4    0         15024             0
#
#        hours_per_week  native_country  income  ...  occupation_5  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['education']=le.fit_transform(data['education'])
data.head()
# Out:
#    age  workclass  fnlwgt  education  education_num       marital_status  \
# 0   39          7   77516          9             13        Never-married
# 1   50          6   83311          9             13   Married-civ-spouse
# 2   38          4  215646         11              9             Divorced
# 3   53          4  234721          1              7   Married-civ-spouse
# 4   28          4  338409          9             13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital_gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital_loss  hours_per_week  native_country  income
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['marital_status']=le.fit_transform(data['marital_status'])
data.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#            occupation    relationship    race      sex  capital_gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital_loss  hours_per_week  native_country  income
# 0             0              40   United-States   <=50K
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['race']=le.fit_transform(data['race'])
data.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#            occupation    relationship  race      sex  capital_gain  \
# 0        Adm-clerical   Not-in-family     4     Male          2174
# 1     Exec-managerial         Husband     4     Male             0
# 2   Handlers-cleaners   Not-in-family     4     Male             0
# 3   Handlers-cleaners         Husband     2     Male             0
# 4      Prof-specialty            Wife     2   Female             0
#
#    capital_loss  hours_per_week  native_country  income
# 0             0              40   United-States   <=50K
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['sex']=le.fit_transform(data['sex'])
data.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#            occupation    relationship  race  sex  capital_gain  capital_loss  \
# 0        Adm-clerical   Not-in-family     4    1          2174             0
# 1     Exec-managerial         Husband     4    1             0             0
# 2   Handlers-cleaners   Not-in-family     4    1             0             0
# 3   Handlers-cleaners         Husband     2    1             0             0
# 4      Prof-specialty            Wife     2    0             0             0
#
#    hours_per_week  native_country  income
# 0              40   United-States   <=50K
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['native_country']=le.fit_transform(data['native_country'])
data.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#            occupation    relationship  race  sex  capital_gain  capital_loss  \
# 0        Adm-clerical   Not-in-family     4    1          2174             0
# 1     Exec-managerial         Husband     4    1             0             0
# 2   Handlers-cleaners   Not-in-family     4    1             0             0
# 3   Handlers-cleaners         Husband     2    1             0             0
# 4      Prof-specialty            Wife     2    0             0             0
#
#    hours_per_week  native_country  income
# 0              40              39   <=50K
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['relationship']=le.fit_transform(data['relationship'])
data.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#            occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0        Adm-clerical             1     4    1          2174             0
# 1     Exec-managerial             0     4    1             0             0
# 2   Handlers-cleaners             1     4    1             0             0
# 3   Handlers-cleaners             0     2    1             0             0
# 4      Prof-specialty             5     2    0             0             0
#
#    hours_per_week  native_country  income
# 0              40              39   <=50K
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['income']=le.fit_transform(data['income'])
data.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#            occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0        Adm-clerical             1     4    1          2174             0
# 1     Exec-managerial             0     4    1             0             0
# 2   Handlers-cleaners             1     4    1             0             0
# 3   Handlers-cleaners             0     2    1             0             0
# 4      Prof-specialty             5     2    0             0             0
#
#    hours_per_week  native_country  income
# 0              40              39       0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['occupation']=le.fit_transform(data['occupation'])
data.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0           1             1     4    1          2174             0
# 1           4             0     4    1             0             0
# 2           6             1     4    1             0             0
# 3           6             0     2    1             0             0
# 4          10             5     2    0             0             0
#
#    hours_per_week  native_country  income
# 0              40              39       0
# 1              13              39       0
# ...

# %%
data.hist(figsize=(12,10),bins=15)
plt.tight_layout()
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data.corr().round(2),annot=True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.pairplot(data=data)
plt.show()

# %%
plt.figure(figsize=(12,5))
data["income"].value_counts().plot(kind="pie",autopct="%1.2f%%")
plt.show()

# %%
plt.figure(figsize=(12,5))
data["sex"].value_counts().plot(kind="pie",autopct="%1.2f%%")
plt.show()

# %%
plt.figure(figsize=(12,5))
data["relationship"].value_counts().plot(kind="pie",autopct="%1.2f%%")
plt.show()
