# %%
import pandas as pd

# %%
data = pd.read_csv("ToyotaCorolla - MLR.csv")
data
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
data['Fuel_Type'] = LE.fit_transform(data['Fuel_Type'])
data.head(1435)
# Out:
#       Price  Age_08_04     KM  Fuel_Type  HP  Automatic    cc  Doors  \
# 0     13500         23  46986          1  90          0  2000      3
# 1     13750         23  72937          1  90          0  2000      3
# 2     13950         24  41711          1  90          0  2000      3
# 3     14950         26  48000          1  90          0  2000      3
# 4     13750         30  38500          1  90          0  2000      3
# ...     ...        ...    ...        ...  ..        ...   ...    ...
# 1430   8450         80  23000          2  86          0  1300      3
# 1431   7500         69  20544          2  86          0  1300      3
# 1432  10845         72  19000          2  86          0  1300      3
# 1433   8500         71  17016          2  86          0  1300      3
# 1434   7250         70  16916          2  86          0  1300      3
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
data['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# 2    1264
# 1     155
# 0      17
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (1436, 11)

# %%
data.dtypes
# Out:
# Price        int64
# Age_08_04    int64
# KM           int64
# Fuel_Type    int32
# HP           int64
# Automatic    int64
# cc           int64
# Doors        int64
# Cylinders    int64
# Gears        int64
# Weight       int64
# dtype: object

# %%
data.isna().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   int32
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int32(1), int64(10)
# memory usage: 117.9 KB

# %%
data.describe()
# Out:
#               Price    Age_08_04             KM    Fuel_Type           HP  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749     1.868384   101.502089
# std     3626.964585    18.599988   37506.448872     0.371572    14.981080
# min     4350.000000     1.000000       1.000000     0.000000    69.000000
# 25%     8450.000000    44.000000   43000.000000     2.000000    90.000000
# 50%     9900.000000    61.000000   63389.500000     2.000000   110.000000
# 75%    11950.000000    70.000000   87020.750000     2.000000   110.000000
# max    32500.000000    80.000000  243000.000000     2.000000   192.000000
#
#          Automatic           cc        Doors  Cylinders        Gears  \
# count  1436.000000   1436.00000  1436.000000     1436.0  1436.000000
# mean      0.055710   1576.85585     4.033426        4.0     5.026462
# std       0.229441    424.38677     0.952677        0.0     0.188510
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# Correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# Pairplot
sns.pairplot(data, x_vars=['Age_08_04', 'KM', 'HP', 'Weight'], y_vars='Price', kind='scatter')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(x=data['Age_08_04'],hist=False)
plt.show()

# %%
sns.distplot(x=data['KM'],hist=False)
plt.show()

# %%
sns.distplot(x=data['HP'],hist=False)
plt.show()

# %%
x=data.iloc[:,1:]
x
# Out:
#       Age_08_04     KM  Fuel_Type   HP  Automatic    cc  Doors  Cylinders  \
# 0            23  46986          1   90          0  2000      3          4
# 1            23  72937          1   90          0  2000      3          4
# 2            24  41711          1   90          0  2000      3          4
# 3            26  48000          1   90          0  2000      3          4
# 4            30  38500          1   90          0  2000      3          4
# ...         ...    ...        ...  ...        ...   ...    ...        ...
# 1431         69  20544          2   86          0  1300      3          4
# 1432         72  19000          2   86          0  1300      3          4
# 1433         71  17016          2   86          0  1300      3          4
# 1434         70  16916          2   86          0  1300      3          4
# 1435         76      1          2  110          0  1600      5          4
#
#       Gears  Weight
# 0         5    1165
# 1         5    1165
# ...

# %%
y=data.iloc[:,0]
y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1431     7500
# 1432    10845
# 1433     8500
# 1434     7250
# 1435     6950
# Name: Price, Length: 1436, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=45)
x_train,x_test,y_train,y_test
# Out:
# (      Age_08_04      KM  Fuel_Type   HP  Automatic    cc  Doors  Cylinders  \
#  568          52   36000          2  110          0  1600      5          4
#  230          44   63451          2   97          0  1400      3          4
#  1129         71  107516          2  110          0  1600      3          4
#  1280         78   73638          2   86          1  1300      4          4
#  184           1       1          2   98          0  1400      4          4
#  ...         ...     ...        ...  ...        ...   ...    ...        ...
#  580          49   31999          2   97          0  1400      3          4
#  163          14    6500          2  110          0  1600      4          4
#  607          62  183500          1   72          0  2000      5          4
#  414          49   97600          2  110          0  1600      3          4
#  971          68   47500          2   86          0  1300      5          4
#
#        Gears  Weight
#  568       5    1075
# ...

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1148, 10), (288, 10), (1148,), (288,))

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr = LinearRegression()
mlr.fit(x_train,y_train)
y_test_pred = mlr.predict(x_test)

# %%
y_test_pred
# Out:
# array([ 8105.54275195, 19105.54698495,  8941.99918461,  9172.15029293,
#         8673.39980168, 13487.27150142, 11154.60584724,  9389.16782562,
#         9664.05515421,  9807.95622308,  7479.49719984,  7870.56710416,
#        16192.27921941, 14495.12226818, 13978.60036947, 10019.72943079,
#        18887.35471752,  8046.45698726, 13528.31519338, 13357.15874429,
#         8380.60843176, 19437.16111825, 13217.71390707, 17301.31293561,
#        15919.68889673,  8126.4370414 , 13277.71278503, 11206.59013207,
#        10721.43570121,  8350.27142659,  7830.10535039,  9598.81955851,
#        10084.56597521, 10381.1904578 ,  8404.13413927, 11700.47424541,
#        10613.77520243, 10675.36384601,  9298.70236122, 11683.74431102,
#         9431.32215547,  7051.62431858,  7772.91451795,  5238.89463828,
#         8916.7673063 , 12865.92130428, 10764.03244268,  6249.00854977,
#         6457.71178769, 10939.85408346, 12665.30065716,  5486.20912769,
# ...

# %%
data.corr()
# Out:
#               Price  Age_08_04        KM  Fuel_Type        HP  Automatic  \
# Price      1.000000  -0.876590 -0.569960  -0.022157  0.314990   0.033081
# Age_08_04 -0.876590   1.000000  0.505672   0.080261 -0.156622   0.031717
# KM        -0.569960   0.505672  1.000000  -0.420586 -0.333538  -0.081854
# Fuel_Type -0.022157   0.080261 -0.420586   1.000000  0.409476   0.069718
# HP         0.314990  -0.156622 -0.333538   0.409476  1.000000   0.013144
# Automatic  0.033081   0.031717 -0.081854   0.069718  0.013144   1.000000
# cc         0.126389  -0.098084  0.102683  -0.277239  0.035856   0.066740
# Doors      0.185326  -0.148359 -0.036197  -0.026935  0.092424  -0.027654
# Cylinders       NaN        NaN       NaN        NaN       NaN        NaN
# Gears      0.063104  -0.005364  0.015023   0.069655  0.209477  -0.098555
# Weight     0.581198  -0.470253 -0.028598  -0.505303  0.089614   0.057249
#
#                  cc     Doors  Cylinders     Gears    Weight
# ...

# %%
mlr.intercept_
# Out:
# -9747.47490063894

# %%
mlr.coef_
# Out:
# array([-1.22156543e+02, -1.80013263e-02,  6.56934579e+02,  2.22117714e+01,
#         3.03036008e+02, -2.83596119e-02, -3.23985359e+01, -5.68434189e-14,
#         7.00117366e+02,  2.02368758e+01])

# %%
error = y_test - y_test_pred

# %%
error
# Out:
# 1166    -155.542752
# 167     1844.453015
# 629    -1191.999185
# 653      777.849707
# 1429     276.600198
#            ...
# 854    -1197.463708
# 47       355.648575
# 617    -2050.630460
# 1090    2376.646684
# 800      483.381601
# Name: Price, Length: 288, dtype: float64

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,mean_absolute_percentage_error,root_mean_squared_error

# %%
r2 = r2_score(y_test,y_test_pred)

# %%
r2
# Out:
# 0.8701016526616703

# %%
mse = mean_squared_error(y_test,y_test_pred)

# %%
mse
# Out:
# 2072332.8735922645

# %%
mae = mean_absolute_error(y_test,y_test_pred)
mae
# Out:
# 1021.7915320594669

# %%
mape = mean_absolute_percentage_error(y_test,y_test_pred)
mape
# Out:
# 0.09555037803804929

# %%
rmse = root_mean_squared_error(y_test,y_test_pred)
rmse
# Out:
# 1439.5599583179105

# %%
plt.scatter(x=x_test['Age_08_04'],y=error)
plt.title('Homoscedsticity Check - Scaled_AGE Vs Error')
plt.xlabel('Scaled_HP')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x=x_test['HP'],y=error)
plt.title('Homoscedsticity Check - Scaled_HP Vs Error')
plt.xlabel('Scaled_HP')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x=x_test['KM'],y=error)
plt.title('Homoscedsticity Check - Scaled_KM Vs Error')
plt.xlabel('Scaled_HP')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x=x_test['Weight'],y=error)
plt.title('Homoscedsticity Check - Scaled_Weight Vs Error')
plt.xlabel('Scaled_HP')
plt.ylabel('Error')
plt.show()

# %%
plt.scatter(x=x_test['Fuel_Type'],y=error)
plt.title('Homoscedsticity Check - Scaled_Fuel_Type Vs Error')
plt.xlabel('Scaled_HP')
plt.ylabel('Error')
plt.show()
